# %%
import cobaya
print(cobaya.__version__)
from cobaya.run import run
from cobaya.yaml import yaml_load_file
# from cobaya.install import install
from cobaya.model import get_model
import hillik_foregrounds as hkf
import hillik_spt
# Out:
# 3.5.4

# %%
import os
import tempfile
import unittest

import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
packages_path = os.environ.get("COBAYA_PACKAGES_PATH") or os.path.join(
    tempfile.gettempdir(), "SPT_packages"
)
packages_path = '/data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/'

cosmo_params = {
    "cosmomc_theta": 0.01040,
    "As": 2.16185225e-09,
    "ombh2": 0.02241,
    "omch2": 0.1188,
    "ns": 0.9686,
    "Alens": 1.0,
    # "tau": 0.060,
    "zrei": 8.0,
    "dz": 1.0,
}

calib_params = {
    "TThighl": {
        "SPT_cal": 1.0,
        "SPT_cal_95": 1.0,
        "SPT_cal_150": 1.0,
        "SPT_cal_220": 1.0,
        "FTS_calibration_error": 1.0,
        },
    "TT": {
        "SPT3G_cal": 1.0,
        "SPT3G_cal_T90": 1.0,
        "SPT3G_cal_T150": 1.0,
        "SPT3G_cal_T220": 1.0,
        "kappa": 0.0
        },
    "EE": {
        "SPT3G_cal": 1.0,
        "SPT3G_cal_E90": 1.0,
        "SPT3G_cal_E150": 1.0,
        "SPT3G_cal_E220": 1.0,
        "kappa": 0.0
        },
    "TE": {
        "SPT3G_cal": 1.0,
        "SPT3G_cal_T90": 1.0,
        "SPT3G_cal_T150": 1.0,
        "SPT3G_cal_T220": 1.0,
        "SPT3G_cal_E90": 1.0,
        "SPT3G_cal_E150": 1.0,
        "SPT3G_cal_E220": 1.0,
        "kappa": 0.0
        },
    "TTTEEE": {
        "SPT3G_cal": 1.0,
        "SPT3G_cal_T90": 1.0,
        "SPT3G_cal_T150": 1.0,
        "SPT3G_cal_T220": 1.0,
        "SPT3G_cal_E90": 1.0,
        "SPT3G_cal_E150": 1.0,
        "SPT3G_cal_E220": 1.0,
        "kappa": 0.0
        },
}

fg_params = {
    "TThighl": dict(
        Acib=1.5,
        Atsz=4.5,
        Aksz=1.5,
	    Apksz=0.,
        Apksz_derived={'derived':True},
        Ahksz_derived={'derived':True},
        Atsz_derived={'derived':True},
        xi=0.1,
        beta_cib=1.5,
        SPT_radio_ps=1.,
        SPT_cib_ps=6.,
        SPT_AdustT=60.,
        ),
    "TT": dict(
        Acib=1.5,
        Atsz=4.5,
        Aksz=1.5,
        xi=0.1,
        beta_cib=1.5,
        SPT3G_radio_ps=10.,
        SPT3G_cib_ps=7.,
        SPT3G_AdustT=60.,
        ),
    "TE": dict(
        SPT3G_AdustT=60.,
        SPT3G_AdustP=6.,
        ),
    "EE": dict(
        SPT3G_AdustP=6.,
        ),
    "TTTEEE": dict(
        SPT3G_AdustT=60.,
        SPT3G_AdustP=6.,
        Acib=1.5,
        Atsz=4.5,
        Aksz=1.5,
        xi=0.1,
        beta_cib=1.5,
        SPT3G_radio_ps=10.,
        SPT3G_cib_ps=7.,
        )
    }

chi2s = {"TThighl": 623.51, "TT": 1024.11, "EE": 439.48, "TE": 678.79, "TTTEEE": 2138.48}

inifiles = ['test_sz_3tp.yaml', 'test_pksz_1rf.yaml', 'test_hksz_1rf.yaml', 'test_tsz_1rf.yaml']
chi2s_sz = [1482.36, 11137.52, 10847.21, 4922.36]

# %%
# mode = 'TTTEEE'
# info = {
#     # "debug": True,
#     "likelihood": {"hillik_spt.{}".format(mode): None},
#     "theory": {"camb": {"extra_args": {"lens_potential_accuracy": 1}, "stop_at_error":True}},
#     "params": {**cosmo_params, **calib_params[mode], **fg_params[mode]},
#     "packages_path": packages_path,
# }

# model = get_model(info)
# print(f"COBAYA/{mode}: {-2*model.loglikes({}, return_derived=False)[0]}, {chi2s[mode]}")

# %%
for mode in chi2s.keys():
    print(f'\n{mode}')
    info = {
        "debug": False,
        "likelihood": {"hillik_spt.{}".format(mode): None},
        "theory": {"camb": {"extra_args": {"lens_potential_accuracy": 1}}},
        "params": {**cosmo_params, **calib_params[mode], **fg_params[mode]},
        "packages_path": packages_path,
    }

    model = get_model(info)
    print(f"COBAYA/{mode}: {-2*model.loglikes({}, return_derived=False)[0]}, {chi2s[mode]}")
# Out:
# TThighl
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:cib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# [cib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# INFO:hillik_spt.tthighl:Initialized!
# [hillik_spt.tthighl] Initialized!
# COBAYA/TThighl: 623.5101076122994, 601.03
#
# TT
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:hillik_spt.tt:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.tt] SPT-3G 2022: Likelihood successfully initialised!
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# COBAYA/TT: 1024.1140638436827, 1024.11
#
# EE
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:hillik_spt.ee:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.ee] SPT-3G 2022: Likelihood successfully initialised!
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# COBAYA/EE: 439.4781687213797, 432.58
#
# TE
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:hillik_spt.te:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.te] SPT-3G 2022: Likelihood successfully initialised!
# COBAYA/TE: 678.7941705078017, 677.91
#
# TTTEEE
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:hillik_spt.ttteee:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.ttteee] SPT-3G 2022: Likelihood successfully initialised!
# COBAYA/TTTEEE: 2138.48625956414, 2138.49

# %%
for inifile in inifiles:
    print(f'\n{inifile}')
    updated_info, sampler = run(yaml_load_file('./'+inifile))
    # sampler.run()
    print(-2.*sampler.logposterior.loglike)
    # model = get_model(info)
# Out:
# test_sz_3tp.yaml
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:tsz:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/dl_tsz_150_bat.dat has lower lmax (filled with 0)
# [tsz] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/dl_tsz_150_bat.dat has lower lmax (filled with 0)
# INFO:szxcib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# [szxcib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# INFO:cib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# [cib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# INFO:hillik_spt.tthighl:Initialized!
# [hillik_spt.tthighl] Initialized!
# INFO:hillik_spt.tt:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.tt] SPT-3G 2022: Likelihood successfully initialised!
# INFO:evaluate:Initialized!
# [evaluate] Initialized!
# INFO:evaluate:Looking for a reference point with non-zero prior.
# [evaluate] Looking for a reference point with non-zero prior.
# INFO:evaluate:Reference point:
#    Acib = 4
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
#    kappa = 0
# [evaluate] Reference point:
#    Acib = 4
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
#    kappa = 0
# INFO:evaluate:Evaluating prior and likelihoods...
# [evaluate] Evaluating prior and likelihoods...
# INFO:evaluate:log-posterior  = -748.19
# [evaluate] log-posterior  = -748.19
# INFO:evaluate:log-prior      = -7.01221
# [evaluate] log-prior      = -7.01221
# INFO:evaluate:   logprior_0 = -7.01221
# [evaluate]    logprior_0 = -7.01221
# INFO:evaluate:log-likelihood = -741.178
# [evaluate] log-likelihood = -741.178
# INFO:evaluate:   chi2_hillik_spt.TThighl = 446.894
# [evaluate]    chi2_hillik_spt.TThighl = 446.894
# INFO:evaluate:   chi2_hillik_spt.TT = 1035.46
# [evaluate]    chi2_hillik_spt.TT = 1035.46
# INFO:evaluate:Derived params:
# [evaluate] Derived params:
# INFO:evaluate:   As = 2.16282e-09
# [evaluate]    As = 2.16282e-09
# INFO:evaluate:   Apksz_derived = 0
# [evaluate]    Apksz_derived = 0
# INFO:evaluate:   Ahksz_derived = 0
# [evaluate]    Ahksz_derived = 0
# INFO:evaluate:   Atsz_derived = 0
# [evaluate]    Atsz_derived = 0
# INFO:evaluate:   beta_dusty = 1.5
# [evaluate]    beta_dusty = 1.5
# 1482.3555732422733
#
# test_pksz_1rf.yaml
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:tsz:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/dl_tsz_150_bat.dat has lower lmax (filled with 0)
# [tsz] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/dl_tsz_150_bat.dat has lower lmax (filled with 0)
# 2024-08-23 16:19:35.464807: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-23 16:19:35.958183: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-23 16:19:35.958242: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-23 16:19:35.972289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-23 16:19:36.040954: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-23 16:19:36.042815: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-23 16:19:45.648294: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:szxcib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# [szxcib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# INFO:cib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# [cib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# INFO:hillik_spt.tthighl:Initialized!
# [hillik_spt.tthighl] Initialized!
# INFO:hillik_spt.tt:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.tt] SPT-3G 2022: Likelihood successfully initialised!
# INFO:evaluate:Initialized!
# [evaluate] Initialized!
# INFO:evaluate:Looking for a reference point with non-zero prior.
# [evaluate] Looking for a reference point with non-zero prior.
# INFO:evaluate:Reference point:
#    beta_cib = 1.75
#    xi = 0.1
#    Acib = 4
#    SPT_radio_ps = 1
#    SPT_cib_ps = 8.6
#    SPT_AdustT = 70
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
# [evaluate] Reference point:
#    beta_cib = 1.75
#    xi = 0.1
#    Acib = 4
#    SPT_radio_ps = 1
#    SPT_cib_ps = 8.6
#    SPT_AdustT = 70
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
# INFO:evaluate:Evaluating prior and likelihoods...
# [evaluate] Evaluating prior and likelihoods...
# INFO:evaluate:log-posterior  = -5595.99
# [evaluate] log-posterior  = -5595.99
# INFO:evaluate:log-prior      = -27.2246
# [evaluate] log-prior      = -27.2246
# INFO:evaluate:   logprior_0 = -27.2246
# [evaluate]    logprior_0 = -27.2246
# INFO:evaluate:log-likelihood = -5568.76
# [evaluate] log-likelihood = -5568.76
# INFO:evaluate:   chi2_hillik_spt.TThighl = 1239.61
# [evaluate]    chi2_hillik_spt.TThighl = 1239.61
# INFO:evaluate:   chi2_hillik_spt.TT = 9897.91
# [evaluate]    chi2_hillik_spt.TT = 9897.91
# INFO:evaluate:Derived params:
# [evaluate] Derived params:
# INFO:evaluate:   As = 2.16282e-09
# [evaluate]    As = 2.16282e-09
# INFO:evaluate:   Apksz_derived = 0
# [evaluate]    Apksz_derived = 0
# INFO:evaluate:   Ahksz_derived = 0
# [evaluate]    Ahksz_derived = 0
# INFO:evaluate:   Atsz_derived = 23.5174
# [evaluate]    Atsz_derived = 23.5174
# INFO:evaluate:   beta_dusty = 1.75
# [evaluate]    beta_dusty = 1.75
# 11137.52144631307
#
# test_hksz_1rf.yaml
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:tsz:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/dl_tsz_150_bat.dat has lower lmax (filled with 0)
# [tsz] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/dl_tsz_150_bat.dat has lower lmax (filled with 0)
# INFO:szxcib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# [szxcib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# INFO:cib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# [cib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# INFO:hillik_spt.tthighl:Initialized!
# [hillik_spt.tthighl] Initialized!
# INFO:hillik_spt.tt:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.tt] SPT-3G 2022: Likelihood successfully initialised!
# INFO:evaluate:Initialized!
# [evaluate] Initialized!
# INFO:evaluate:Looking for a reference point with non-zero prior.
# [evaluate] Looking for a reference point with non-zero prior.
# INFO:evaluate:Reference point:
#    beta_cib = 1.75
#    xi = 0.1
#    Acib = 4
#    SPT_radio_ps = 1
#    SPT_cib_ps = 8.6
#    SPT_AdustT = 70
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
# [evaluate] Reference point:
#    beta_cib = 1.75
#    xi = 0.1
#    Acib = 4
#    SPT_radio_ps = 1
#    SPT_cib_ps = 8.6
#    SPT_AdustT = 70
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
# INFO:evaluate:Evaluating prior and likelihoods...
# [evaluate] Evaluating prior and likelihoods...
# INFO:evaluate:log-posterior  = -5450.83
# [evaluate] log-posterior  = -5450.83
# INFO:evaluate:log-prior      = -27.2246
# [evaluate] log-prior      = -27.2246
# INFO:evaluate:   logprior_0 = -27.2246
# [evaluate]    logprior_0 = -27.2246
# INFO:evaluate:log-likelihood = -5423.61
# [evaluate] log-likelihood = -5423.61
# INFO:evaluate:   chi2_hillik_spt.TThighl = 1325.8
# [evaluate]    chi2_hillik_spt.TThighl = 1325.8
# INFO:evaluate:   chi2_hillik_spt.TT = 9521.42
# [evaluate]    chi2_hillik_spt.TT = 9521.42
# INFO:evaluate:Derived params:
# [evaluate] Derived params:
# INFO:evaluate:   As = 2.16282e-09
# [evaluate]    As = 2.16282e-09
# INFO:evaluate:   Apksz_derived = 0
# [evaluate]    Apksz_derived = 0
# INFO:evaluate:   Ahksz_derived = 3.42926
# [evaluate]    Ahksz_derived = 3.42926
# INFO:evaluate:   Atsz_derived = 0
# [evaluate]    Atsz_derived = 0
# INFO:evaluate:   beta_dusty = 1.75
# [evaluate]    beta_dusty = 1.75
# 10847.212019434044
#
# test_tsz_1rf.yaml
# INFO:camb:`camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# [camb] `camb` module loaded successfully from /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/software/CAMB/camb
# INFO:szxcib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# [szxcib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/sz_x_cib_template.dat has lower lmax (filled with 0)
# INFO:cib:WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# [cib] WARNING: template /data/glx-calcul3/data1/agorce/CMB_reio/HillikWork_temp/modules/data/foregrounds/cib_extra.dat has lower lmax (filled with 0)
# INFO:hillik_spt.tthighl:Initialized!
# [hillik_spt.tthighl] Initialized!
# INFO:hillik_spt.tt:SPT-3G 2022: Likelihood successfully initialised!
# [hillik_spt.tt] SPT-3G 2022: Likelihood successfully initialised!
# INFO:evaluate:Initialized!
# [evaluate] Initialized!
# INFO:evaluate:Looking for a reference point with non-zero prior.
# [evaluate] Looking for a reference point with non-zero prior.
# INFO:evaluate:Reference point:
#    beta_cib = 1.75
#    xi = 0.1
#    Acib = 4
#    SPT_radio_ps = 1
#    SPT_cib_ps = 8.6
#    SPT_AdustT = 70
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
#    kappa = 0
# [evaluate] Reference point:
#    beta_cib = 1.75
#    xi = 0.1
#    Acib = 4
#    SPT_radio_ps = 1
#    SPT_cib_ps = 8.6
#    SPT_AdustT = 70
#    SPT_cal = 0.96
#    SPT_cal_95 = 1
#    SPT_cal_150 = 1
#    SPT_cal_220 = 1
#    SPT3G_cal_T90 = 1
#    SPT3G_cal_T150 = 0.9975
#    SPT3G_cal_T220 = 0.993
#    SPT3G_AdustT = 25
#    SPT3G_radio_ps = 11
#    SPT3G_cib_ps = 5
#    SPT3G_cal = 1
#    kappa = 0
# INFO:evaluate:Evaluating prior and likelihoods...
# [evaluate] Evaluating prior and likelihoods...
# INFO:evaluate:log-posterior  = -2481.62
# [evaluate] log-posterior  = -2481.62
# INFO:evaluate:log-prior      = -20.4373
# [evaluate] log-prior      = -20.4373
# INFO:evaluate:   logprior_0 = -20.4373
# [evaluate]    logprior_0 = -20.4373
# INFO:evaluate:log-likelihood = -2461.18
# [evaluate] log-likelihood = -2461.18
# INFO:evaluate:   chi2_hillik_spt.TThighl = 3867.8
# [evaluate]    chi2_hillik_spt.TThighl = 3867.8
# INFO:evaluate:   chi2_hillik_spt.TT = 1054.56
# [evaluate]    chi2_hillik_spt.TT = 1054.56
# INFO:evaluate:Derived params:
# [evaluate] Derived params:
# INFO:evaluate:   As = 2.16282e-09
# [evaluate]    As = 2.16282e-09
# INFO:evaluate:   Apksz_derived = 0
# [evaluate]    Apksz_derived = 0
# INFO:evaluate:   Ahksz_derived = 0
# [evaluate]    Ahksz_derived = 0
# INFO:evaluate:   Atsz_derived = 23.5174
# [evaluate]    Atsz_derived = 23.5174
# INFO:evaluate:   beta_dusty = 1.75
# [evaluate]    beta_dusty = 1.75
# 4922.358393910577

# %%
# inifile = './test_sz_3tp.yaml'
# print(f'\n{inifile}')
# updated_info, sampler = run(yaml_load_file('./'+inifile))
# # sampler.run()
# print(-2.*sampler.logposterior.loglike)
# # model = get_model(info)
